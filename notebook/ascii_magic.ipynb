# %%
# pip install ascii_magic

# %%
import colorama
from ascii_magic import AsciiArt

# %%
# my_art = AsciiArt.from_image('bem_te_vi.jpg')
# my_art.to_terminal()

# %%
# my_art = AsciiArt.from_image('bem_te_vi.jpg')
# colorama.init()
# my_art.to_terminal()
